# %%
import sys
import os
import json
sys.path.append(os.path.abspath(os.getcwd() + '/..'))
import src.features.tree
import importlib
importlib.reload(src.features.tree)
from src.features.tree import Tree, DataTree, OrAndTree, AndOrTree, DataOnlyTree, dfs, LabeledTree, TemplateTree

# %%
jpn_pos_restrictions_file = os.path.abspath(
    os.getcwd() + '/../data/crafted/jpn_pos_restrictions.json')
with open(jpn_pos_restrictions_file, 'r') as f:
    pos_dict = json.load(f)
TemplateTree.prepare_restrictions(pos_dict)
print(json.dumps(pos_dict, indent='    '))
with open(jpn_pos_restrictions_file, 'r') as f:
    pos_dict = json.load(f)
# Out:
# {
#     "expression": {
#         "parents": [],
#         "label": null,
#         "_children": [
#             "whitespace",
#             "symbol",
#             "word",
#             "multiword",
#             "syllabary",
#             "alphabet"
#         ],
#         "_depth": 0
#     },
#     "whitespace": {
#         "parents": [
#             "expression"
#         ],
#         "label": "segment",
#         "_children": [],
#         "_depth": 1
#     },
#     "symbol": {
#         "parents": [
#             "expression"
#         ],
#         "label": "segment",
#         "_children": [
#             "punctuation"
#         ],
#         "_depth": 1
#     },
#     "word": {
#         "parents": [
#             "expression"
#         ],
#         "label": "segment",
#         "_children": [
#             "adverb",
#             "noun",
#             "adjective",
#             "verb",
#             "copula",
#             "particle",
#             "dependent",
#             "conjunction",
#             "interjection",
#             "numeral",
#             "prefix",
#             "suffix",
#             "auxiliary",
#             "demonstrative",
#             "pronoun",
#             "suru verb"
#         ],
#         "_depth": 1
#     },
#     "multiword": {
#         "parents": [
#             "expression"
#         ],
#         "label": "segment",
#         "_children": [
#             "adverb",
#             "noun",
#             "adjective",
#             "verb",
#             "copula",
#             "particle",
#             "dependent",
#             "conjunction",
#             "interjection",
#             "numeral",
#             "prefix",
#             "suffix",
#             "auxiliary",
#             "demonstrative",
#             "pronoun",
#             "suru verb"
#         ],
#         "_depth": 1
#     },
#     "punctuation": {
#         "parents": [
#             "symbol"
#         ],
#         "label": "class",
#         "_children": [
#             "period",
#             "comma",
#             "opening bracket",
#             "closing bracket"
#         ],
#         "_depth": 2
#     },
#     "period": {
#         "parents": [
#             "punctuation"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "comma": {
#         "parents": [
#             "punctuation"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "opening bracket": {
#         "parents": [
#             "punctuation"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "closing bracket": {
#         "parents": [
#             "punctuation"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "adverb": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "class",
#         "_children": [
#             "quotable",
#             "adverbial noun",
#             "temporal noun"
#         ],
#         "_depth": 2
#     },
#     "quotable": {
#         "parents": [
#             "adverb"
#         ],
#         "label": "quotation",
#         "_children": [],
#         "_depth": 3
#     },
#     "noun": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "class",
#         "_children": [
#             "common noun",
#             "adverbial noun",
#             "temporal noun",
#             "dependent noun",
#             "proper noun",
#             "prenominal"
#         ],
#         "_depth": 2
#     },
#     "common noun": {
#         "parents": [
#             "noun"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "adverbial noun": {
#         "parents": [
#             "noun",
#             "adverb"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "temporal noun": {
#         "parents": [
#             "noun",
#             "adverb"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "dependent noun": {
#         "parents": [
#             "noun",
#             "dependent"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "proper noun": {
#         "parents": [
#             "noun"
#         ],
#         "label": "class",
#         "_children": [
#             "organization name",
#             "place name",
#             "person name",
#             "other name"
#         ],
#         "_depth": 3
#     },
#     "organization name": {
#         "parents": [
#             "proper noun"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 4
#     },
#     "place name": {
#         "parents": [
#             "proper noun"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 4
#     },
#     "person name": {
#         "parents": [
#             "proper noun"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 4
#     },
#     "other name": {
#         "parents": [
#             "proper noun"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 4
#     },
#     "adjective": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "class",
#         "_children": [
#             "i-adjective",
#             "na-adjective",
#             "nari-adjective",
#             "no-adjective",
#             "ku-adjective",
#             "shiku-adjective",
#             "taru-adjective",
#             "kari-adjective",
#             "pre-noun adjectival"
#         ],
#         "_depth": 2
#     },
#     "i-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [
#             "yoi/ii class",
#             "a/u/o row",
#             "i row",
#             "regular",
#             "ookii special class"
#         ],
#         "_depth": 3
#     },
#     "na-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [
#             "regular",
#             "onaji special class"
#         ],
#         "_depth": 3
#     },
#     "nari-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "no-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "ku-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "shiku-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "taru-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "kari-adjective": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "pre-noun adjectival": {
#         "parents": [
#             "adjective"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "yoi/ii class": {
#         "parents": [
#             "i-adjective"
#         ],
#         "label": "variation",
#         "_children": [],
#         "_depth": 4
#     },
#     "a/u/o row": {
#         "parents": [
#             "i-adjective"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "i row": {
#         "parents": [
#             "i-adjective"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "regular": {
#         "parents": [
#             "quintigrade",
#             "monograde",
#             "bigrade",
#             "quadrigrade",
#             "i-adjective",
#             "na-adjective"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "ookii special class": {
#         "parents": [
#             "i-adjective"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "onaji special class": {
#         "parents": [
#             "na-adjective"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "verb": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "class",
#         "_children": [
#             "monograde",
#             "bigrade",
#             "quadrigrade",
#             "quintigrade",
#             "k-irregular",
#             "s-irregular",
#             "n-irregular",
#             "r-irregular",
#             "masu",
#             "irregular",
#             "prenominal",
#             "transitive",
#             "intransitive"
#         ],
#         "_depth": 2
#     },
#     "monograde": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [
#             "regular",
#             "upper class",
#             "lower class",
#             "ra column",
#             "kureru special class",
#             "-zuru ending"
#         ],
#         "_depth": 3
#     },
#     "bigrade": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [
#             "regular",
#             "upper class",
#             "lower class",
#             "a column",
#             "ka column",
#             "ga column",
#             "sa column",
#             "za column",
#             "ta column",
#             "da column",
#             "na column",
#             "ha column",
#             "ba column",
#             "ma column",
#             "ya column",
#             "ra column",
#             "wa column"
#         ],
#         "_depth": 3
#     },
#     "quadrigrade": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [
#             "regular",
#             "ka column",
#             "ga column",
#             "sa column",
#             "ta column",
#             "na column",
#             "ha column",
#             "ba column",
#             "ma column",
#             "ra column"
#         ],
#         "_depth": 3
#     },
#     "quintigrade": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [
#             "regular",
#             "a column",
#             "ka column",
#             "ga column",
#             "sa column",
#             "ta column",
#             "na column",
#             "ba column",
#             "ma column",
#             "ra column",
#             "-aru special class",
#             "-'u special class",
#             "iku/yuku special class",
#             "uru special class",
#             "-ru irregular"
#         ],
#         "_depth": 3
#     },
#     "k-irregular": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "s-irregular": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [
#             "suru class",
#             "su class"
#         ],
#         "_depth": 3
#     },
#     "n-irregular": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "r-irregular": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "masu": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "irregular": {
#         "parents": [
#             "verb"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "upper class": {
#         "parents": [
#             "bigrade",
#             "monograde"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 4
#     },
#     "lower class": {
#         "parents": [
#             "bigrade",
#             "monograde"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 4
#     },
#     "a column": {
#         "parents": [
#             "quintigrade",
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ka column": {
#         "parents": [
#             "quintigrade",
#             "quadrigrade",
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ga column": {
#         "parents": [
#             "quintigrade",
#             "bigrade",
#             "quadrigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "sa column": {
#         "parents": [
#             "quintigrade",
#             "quadrigrade",
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "za column": {
#         "parents": [
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ta column": {
#         "parents": [
#             "quintigrade",
#             "bigrade",
#             "quadrigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "da column": {
#         "parents": [
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "na column": {
#         "parents": [
#             "quintigrade",
#             "bigrade",
#             "quadrigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ha column": {
#         "parents": [
#             "quadrigrade",
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ba column": {
#         "parents": [
#             "quintigrade",
#             "bigrade",
#             "quadrigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ma column": {
#         "parents": [
#             "quintigrade",
#             "bigrade",
#             "quadrigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ya column": {
#         "parents": [
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "ra column": {
#         "parents": [
#             "quintigrade",
#             "quadrigrade",
#             "bigrade",
#             "monograde"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "wa column": {
#         "parents": [
#             "bigrade"
#         ],
#         "label": "ending",
#         "_children": [],
#         "_depth": 4
#     },
#     "-aru special class": {
#         "parents": [
#             "quintigrade"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "-'u special class": {
#         "parents": [
#             "quintigrade"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "iku/yuku special class": {
#         "parents": [
#             "quintigrade"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "uru special class": {
#         "parents": [
#             "quintigrade"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "-ru irregular": {
#         "parents": [
#             "quintigrade"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "kureru special class": {
#         "parents": [
#             "monograde"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "-zuru ending": {
#         "parents": [
#             "monograde"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "suru class": {
#         "parents": [
#             "s-irregular"
#         ],
#         "label": "inflection",
#         "_children": [
#             "suru ending",
#             "-suru ending"
#         ],
#         "_depth": 4
#     },
#     "su class": {
#         "parents": [
#             "s-irregular"
#         ],
#         "label": "inflection",
#         "_children": [],
#         "_depth": 4
#     },
#     "suru ending": {
#         "parents": [
#             "suru class"
#         ],
#         "label": "inclusion",
#         "_children": [],
#         "_depth": 5
#     },
#     "-suru ending": {
#         "parents": [
#             "suru class"
#         ],
#         "label": "inclusion",
#         "_children": [],
#         "_depth": 5
#     },
#     "copula": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 2
#     },
#     "particle": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "class",
#         "_children": [
#             "case particle",
#             "adverbial particle",
#             "sentence-ending particle"
#         ],
#         "_depth": 2
#     },
#     "case particle": {
#         "parents": [
#             "particle"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "adverbial particle": {
#         "parents": [
#             "particle"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "sentence-ending particle": {
#         "parents": [
#             "particle"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "dependent": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "class",
#         "_children": [
#             "dependent noun",
#             "non-inflectional",
#             "nu",
#             "darou",
#             "souda",
#             "beshi/gotoshi"
#         ],
#         "_depth": 2
#     },
#     "non-inflectional": {
#         "parents": [
#             "dependent"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "nu": {
#         "parents": [
#             "dependent"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "darou": {
#         "parents": [
#             "dependent"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "souda": {
#         "parents": [
#             "dependent"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "beshi/gotoshi": {
#         "parents": [
#             "dependent"
#         ],
#         "label": "class",
#         "_children": [],
#         "_depth": 3
#     },
#     "conjunction": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "conjunction",
#         "_children": [],
#         "_depth": 2
#     },
#     "interjection": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "interjection",
#         "_children": [],
#         "_depth": 2
#     },
#     "numeral": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "numeral",
#         "_children": [],
#         "_depth": 2
#     },
#     "prefix": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "affix",
#         "_children": [
#             "attached to noun",
#             "attached to verb",
#             "attached to i-adjective",
#             "attached to na-adjective"
#         ],
#         "_depth": 2
#     },
#     "suffix": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "affix",
#         "_children": [
#             "attached to noun",
#             "attached to predicate",
#             "counter"
#         ],
#         "_depth": 2
#     },
#     "attached to noun": {
#         "parents": [
#             "suffix",
#             "prefix"
#         ],
#         "label": "attachment",
#         "_children": [],
#         "_depth": 3
#     },
#     "attached to verb": {
#         "parents": [
#             "prefix"
#         ],
#         "label": "attachment",
#         "_children": [],
#         "_depth": 3
#     },
#     "attached to i-adjective": {
#         "parents": [
#             "prefix"
#         ],
#         "label": "attachment",
#         "_children": [],
#         "_depth": 3
#     },
#     "attached to na-adjective": {
#         "parents": [
#             "prefix"
#         ],
#         "label": "attachment",
#         "_children": [],
#         "_depth": 3
#     },
#     "attached to predicate": {
#         "parents": [
#             "suffix"
#         ],
#         "label": "attachment",
#         "_children": [],
#         "_depth": 3
#     },
#     "counter": {
#         "parents": [
#             "suffix"
#         ],
#         "label": "attachment",
#         "_children": [],
#         "_depth": 3
#     },
#     "auxiliary": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "auxiliary",
#         "_children": [],
#         "_depth": 2
#     },
#     "demonstrative": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "demonstrative",
#         "_children": [],
#         "_depth": 2
#     },
#     "prenominal": {
#         "parents": [
#             "noun",
#             "verb"
#         ],
#         "label": "prenominal",
#         "_children": [],
#         "_depth": 3
#     },
#     "pronoun": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "pronoun",
#         "_children": [],
#         "_depth": 2
#     },
#     "suru verb": {
#         "parents": [
#             "word",
#             "multiword"
#         ],
#         "label": "suru",
#         "_children": [
#             "transitive",
#             "intransitive"
#         ],
#         "_depth": 2
#     },
#     "transitive": {
#         "parents": [
#             "verb",
#             "suru verb"
#         ],
#         "label": "transitivity",
#         "_children": [],
#         "_depth": 3
#     },
#     "intransitive": {
#         "parents": [
#             "verb",
#             "suru verb"
#         ],
#         "label": "transitivity",
#         "_children": [],
#         "_depth": 3
#     },
#     "syllabary": {
#         "parents": [
#             "expression"
#         ],
#         "label": "writing system",
#         "_children": [
#             "katakana"
#         ],
#         "_depth": 1
#     },
#     "alphabet": {
#         "parents": [
#             "expression"
#         ],
#         "label": "writing system",
#         "_children": [],
#         "_depth": 1
#     },
#     "katakana": {
#         "parents": [
#             "syllabary"
#         ],
#         "label": "writing system",
#         "_children": [],
#         "_depth": 2
#     }
# }

# %%
# Pronouns are modeled disjoint from nouns to allow for better inter-language
# compatibility
#  
# See https://japanese.stackexchange.com/a/23578 : temporal noun
# != adverbial noun, temporal noun -> noun, temporal noun -> adverb
 
# XXX Currently, there are no common classes for generic i-adj. (non-'yoi/ii
# class' adjectives); the same goes for some other word classes
# 
# XXX Monitor performance of JUMAN++ adverbial nouns, beshi/gotoshi, 名詞性特殊
# 接尾辞
# 
# XXX Maybe make one special verb class for uru
# XXX Move aux./dep. to higher layers in tree?
# 
# XXX 'wa column' and 'a column' may be the same, with 'ゑ' conjugation being a
# special class in classical Japanese; JUMAN++ classifies 'a column' godan verbs
# as belonging to 'ワ行', not 'ア行'

# %%
lexeme_pos_tree = TemplateTree.parse(['ra column', '-aru special class', 'monograde', 'upper class', 'prefix', 'noun'],
                        pos_dict)
print(lexeme_pos_tree)
# Out:
# ╶╴'expression'
#   ╰──╴'segment': 'word'
#       ├─╮ 'class'
#       │ ├╴'verb'
#       │ │ ╰─╮ 'class'
#       │ │   ├╴'quintigrade'
#       │ │   │ ├──╴'ending': 'ra column'
#       │ │   │ ╰──╴'inflection': '-aru special class'
#       │ │  ╶│╌╌╌╌╌╌╴
#       │ │   ╰╴'monograde'
#       │ │     ╰──╴'class': 'upper class'
#       │╶│╌╌╌╌╌╌╴
#       │ ╰╴'noun'
#      ╶│╴ ╶╌╌╌╌╌╴
#       ╰──╴'affix': 'prefix'

# %%
token_pos_tree = DataOnlyTree('expression')
word = token_pos_tree.attach('word')
adjective = word.attach('adjective')
adjective.attach('no-adjective')
adjective.attach('na-adjective')
noun = word.attach('noun')
noun.attach('proper noun')
verb = word.attach('verb')
verb.attach('monograde').attach('upper class')
verb.attach('monograde').attach('lower class')
verb.attach('transitive')
word.attach('suru verb')
word.attach('suffix')

match_score, match_result = lexeme_pos_tree.score(token_pos_tree)
print(lexeme_pos_tree)
print()
dfs(token_pos_tree)
print()
print(match_score)
print()
if match_result is not None:
    dfs(match_result)
    print()
# Out:
# ╶╴'expression'
#   ╰──╴'segment': 'word'
#       ├─╮ 'class'
#       │ ├╴'verb'
#       │ │ ╰─╮ 'class'
#       │ │   ├╴'quintigrade'
#       │ │   │ ├──╴'ending': 'ra column'
#       │ │   │ ╰──╴'inflection': '-aru special class'
#       │ │  ╶│╌╌╌╌╌╌╴
#       │ │   ╰╴'monograde'
#       │ │     ╰──╴'class': 'upper class'
#       │╶│╌╌╌╌╌╌╴
#       │ ╰╴'noun'
#      ╶│╴ ╶╌╌╌╌╌╴
#       ╰──╴'affix': 'prefix'
#
# ╶╴'expression'
#   ╰╴'word'
#     ├╴'adjective'
#     │ ├╴'no-adjective'
#     │ ╰╴'na-adjective'
#     ├╴'noun'
#     │ ╰╴'proper noun'
#     ├╴'verb'
#     │ ├╴'monograde'
#     │ │ ╰╴'upper class'
#     │ ├╴'monograde'
#     │ │ ╰╴'lower class'
#     │ ╰╴'transitive'
#     ├╴'suru verb'
#     ╰╴'suffix'
#
# 0.4518249661206786
#
# ╶╴'expression'
#   ╰╴'word'
#     ╰╴'noun'
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/virtualenvs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/virtualenvs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)
# /home/jbetz/Documents/Courses/UHH_MSc_Informatik/Master_Project/personalized_reading_support/src/features/tree.py:1030: DeprecationWarning: Call to deprecated function (or staticmethod) dfs.
#   dfs(node, prefix + ('\u2502 ' if next_sibling else '  '), i < l - 1)

# %%
print(lexeme_pos_tree, end='\n\n')
token_pos_tree = TemplateTree.parse(['verb', 'quintigrade', 'monograde', 'upper class'], pos_dict)
print(token_pos_tree, end='\n\n')
match_score, match_result = lexeme_pos_tree.score(token_pos_tree)
print(match_score, end='\n\n')
print(match_result)
# Out:
# ╶╴'expression'
#   ╰──╴'segment': 'word'
#       ├─╮ 'class'
#       │ ├╴'verb'
#       │ │ ╰─╮ 'class'
#       │ │   ├╴'quintigrade'
#       │ │   │ ├──╴'ending': 'ra column'
#       │ │   │ ╰──╴'inflection': '-aru special class'
#       │ │  ╶│╌╌╌╌╌╌╴
#       │ │   ╰╴'monograde'
#       │ │     ╰──╴'class': 'upper class'
#       │╶│╌╌╌╌╌╌╴
#       │ ╰╴'noun'
#      ╶│╴ ╶╌╌╌╌╌╴
#       ╰──╴'affix': 'prefix'
#
# ╶╴'expression'
#   ╰──╴'segment': 'word'
#       ╰──╴'class': 'verb'
#           ╰─╮ 'class'
#             ├╴'quintigrade'
#            ╶│╌╌╌╌╌╌╴
#             ╰╴'monograde'
#               ╰──╴'class': 'upper class'
#
# 0.6950893220270075
#
# ╶╴'expression'
#   ╰──╴'segment': 'word'
#       ╰──╴'class': 'verb'
#           ╰──╴'class': 'monograde'
#               ╰──╴'class': 'upper class'

# %%
tree = LabeledTree('expression')
tree['segment', 'word'] = LabeledTree('word')
tree['segment'] = LabeledTree('multiword')
verb = tree['segment', 'word', 'class'] = LabeledTree('verb')
noun = tree['segment', 'word', 'class'] = LabeledTree('noun')
adj = tree['segment', 'word', 'class'] = LabeledTree('adjective')
tree['segment', 'word', 'pronoun'] = LabeledTree('pronoun')
tree['segment', 'word', 'affix'] = LabeledTree('suffix')
tree['segment', 'word', 'affix'] = LabeledTree('prefix')
adj['class'] = LabeledTree('i-adjective')
adj['class', 'i-adjective', 'variation'] = LabeledTree('yoi/ii class')
adj['class'] = LabeledTree('ku-adjective')
adj['class'] = LabeledTree('na-adjective')
verb['class'] = LabeledTree('quintigrade')
verb['class'] = LabeledTree('monograde')
tree['segment', 'word', 'suru'] = LabeledTree('suru verb')
tree['segment', 'word', 'suru', 'suru verb', 'class'] = LabeledTree('noun')
verb['transitivity'] = LabeledTree('transitive')
verb['transitivity'] = LabeledTree('intransitive')
del tree['segment', 'word', 'class', 'verb', 'transitivity', 'intransitive']
print(tree)

# Toy grammar of German
deu_pos_restrictions_file = os.path.abspath(
    os.getcwd() + '/../data/crafted/deu_pos_restrictions.json')
tree = TemplateTree('expression', restrictions=deu_pos_restrictions_file)
word = tree['word'] = TemplateTree('word')
multiword = tree['multiword'] = TemplateTree('multiword')
for structure in (word, multiword):
    structure['verb'] = TemplateTree('verb')
    structure['verb'].attach('weak')
    structure['verb'].attach('strong')
    structure['verb'].attach('irregular')
    structure['verb', 'transitive'] = TemplateTree('transitive')
    structure['verb', 'intransitive'] = TemplateTree('intransitive')
    structure['noun'] = TemplateTree('noun')
    structure['noun', 'male'] = TemplateTree('male')
    structure['noun', 'female'] = TemplateTree('female')
    structure['noun', 'neuter'] = TemplateTree('neuter')
    structure['noun', 'proper'] = TemplateTree('proper')
    # tree[structure._data, 'article'] = TemplateTree('article')
    # tree[structure._data, 'article', 'indefinite'] = TemplateTree('indefinite')
    # structure['article', 'definite'] = TemplateTree('definite')
    pronoun = structure['pronoun'] = TemplateTree('pronoun')
    pronoun['indefinite'] = TemplateTree('indefinite')
    pronoun['personal'] = TemplateTree('personal')
    pronoun['posessive'] = TemplateTree('posessive')
    pronoun['reflexive'] = TemplateTree('reflexive')
    pronoun['demonstrative'] = TemplateTree('demonstrative')
    pronoun['interrogative'] = TemplateTree('interrogative')
    pronoun['relative'] = TemplateTree('relative')
    structure['adjective'] = TemplateTree('adjective')
    structure['adjective', 'gradable'] = TemplateTree('gradable')
    structure['adjective', 'non-gradable'] = TemplateTree('non-gradable')
    structure['numeral'] = TemplateTree('numeral')
    structure['numeral', 'cardinal'] = TemplateTree('cardinal')
    structure['numeral', 'ordinal'] = TemplateTree('ordinal')
    structure['adverb'] = TemplateTree('adverb')
    structure['preposition'] = TemplateTree('preposition')
    structure['conjunction'] = TemplateTree('conjunction')
    structure['conjunction', 'subordinate'] = TemplateTree('subordinate')
    structure['conjunction', 'coordinate'] = TemplateTree('coordinate')
    structure['interjection'] = TemplateTree('interjection')
    structure['prefix'] = TemplateTree('prefix')
    structure['suffix'] = TemplateTree('suffix')
for label, children in multiword[()]:
    print(label)
    for child in children:
        print(repr(child))

print('word' in tree)
print(tree.is_valid_data('verb'))
print(tree)
print(tree._restrictions['article'])
print(tree['word', 'verb'])
# Out:
# ╶╴'expression'
#   ╰─╮ 'segment'
#     ├╴'word'
#     │ ├─╮ 'class'
#     │ │ ├╴'verb'
#     │ │ │ ├─╮ 'class'
#     │ │ │ │ ├╴'quintigrade'
#     │ │ │ │ ╰╴'monograde'
#     │ │ │╶│╴ ╶╌╌╌╌╌╴
#     │ │ │ ╰──╴'transitivity': 'transitive'
#     │ │╶│╌╌╌╌╌╌╴
#     │ │ ├╴'noun'
#     │ │╶│╌╌╌╌╌╌╴
#     │ │ ╰╴'adjective'
#     │ │   ╰─╮ 'class'
#     │ │     ├╴'i-adjective'
#     │ │     │ ╰──╴'variation': 'yoi/ii class'
#     │ │    ╶│╌╌╌╌╌╌╴
#     │ │     ├╴'ku-adjective'
#     │ │     ╰╴'na-adjective'
#     │╶│╴ ╶╌╌╌╌╌╴
#     │ ├──╴'pronoun': 'pronoun'
#     │╶│╴ ╶╌╌╌╌╌╴
#     │ ├─╮ 'affix'
#     │ │ ├╴'suffix'
#     │ │ ╰╴'prefix'
#     │╶│╴ ╶╌╌╌╌╌╴
#     │ ╰──╴'suru': 'suru verb'
#     │     ╰──╴'class': 'noun'
#    ╶│╌╌╌╌╌╌╴
#     ╰╴'multiword'
# class
# TemplateTree('verb', {'class': {TemplateTree('weak'), TemplateTree('strong'), TemplateTree('irregular')}, 'transitivity': {TemplateTree('transitive'), TemplateTree('intransitive')}})
# TemplateTree('noun', {'gender': {TemplateTree('male'), TemplateTree('female'), TemplateTree('neuter')}, 'property': {TemplateTree('proper')}})
# TemplateTree('pronoun', {'class': {TemplateTree('indefinite'), TemplateTree('demonstrative')}, 'inflection': {TemplateTree('personal'), TemplateTree('posessive'), TemplateTree('reflexive')}, 'interrogation': {TemplateTree('interrogative'), TemplateTree('relative')}})
# TemplateTree('adjective', {'class': {TemplateTree('gradable'), TemplateTree('non-gradable')}})
# TemplateTree('adverb')
# TemplateTree('preposition')
# TemplateTree('conjunction', {'class': {TemplateTree('subordinate'), TemplateTree('coordinate')}})
# numeric
# TemplateTree('numeral', {'class': {TemplateTree('cardinal'), TemplateTree('ordinal')}})
# interjection
# TemplateTree('interjection')
# affix
# TemplateTree('prefix')
# TemplateTree('suffix')
# True
# True
# ╶╴'expression'
#   ╰─╮ 'segment'
#     ├╴'word'
#     │ ├─╮ 'class'
#     │ │ ├╴'verb'
#     │ │ │ ├─╮ 'class'
#     │ │ │ │ ├╴'weak'
#     │ │ │ │ ├╴'strong'
#     │ │ │ │ ╰╴'irregular'
#     │ │ │╶│╴ ╶╌╌╌╌╌╴
#     │ │ │ ╰─╮ 'transitivity'
#     │ │ │   ├╴'transitive'
#     │ │ │   ╰╴'intransitive'
#     │ │╶│╌╌╌╌╌╌╴
#     │ │ ├╴'noun'
#     │ │ │ ├─╮ 'gender'
#     │ │ │ │ ├╴'male'
#     │ │ │ │ ├╴'female'
#     │ │ │ │ ╰╴'neuter'
#     │ │ │╶│╴ ╶╌╌╌╌╌╴
#     │ │ │ ╰──╴'property': 'proper'
#     │ │╶│╌╌╌╌╌╌╴
#     │ │ ├╴'pronoun'
#     │ │ │ ├─╮ 'class'
#     │ │ │ │ ├╴'indefinite'
#     │ │ │ │ ╰╴'demonstrative'
#     │ │ │╶│╴ ╶╌╌╌╌╌╴
#     │ │ │ ├─╮ 'inflection'
#     │ │ │ │ ├╴'personal'
#     │ │ │ │ ├╴'posessive'
#     │ │ │ │ ╰╴'reflexive'
#     │ │ │╶│╴ ╶╌╌╌╌╌╴
#     │ │ │ ╰─╮ 'interrogation'
#     │ │ │   ├╴'interrogative'
#     │ │ │   ╰╴'relative'
#     │ │╶│╌╌╌╌╌╌╴
#     │ │ ├╴'adjective'
#     │ │ │ ╰─╮ 'class'
#     │ │ │   ├╴'gradable'
#     │ │ │   ╰╴'non-gradable'
#     │ │╶│╌╌╌╌╌╌╴
#     │ │ ├╴'adverb'
#     │ │ ├╴'preposition'
#     │ │╶│╌╌╌╌╌╌╴
#     │ │ ╰╴'conjunction'
#     │ │   ╰─╮ 'class'
#     │ │     ├╴'subordinate'
#     │ │     ╰╴'coordinate'
#     │╶│╴ ╶╌╌╌╌╌╴
#     │ ├──╴'numeric': 'numeral'
#     │ │   ╰─╮ 'class'
#     │ │     ├╴'cardinal'
#     │ │     ╰╴'ordinal'
#     │╶│╴ ╶╌╌╌╌╌╴
#     │ ├──╴'interjection': 'interjection'
#     │╶│╴ ╶╌╌╌╌╌╴
#     │ ╰─╮ 'affix'
#     │   ├╴'prefix'
#     │   ╰╴'suffix'
#    ╶│╌╌╌╌╌╌╴
#     ╰╴'multiword'
#       ├─╮ 'class'
#       │ ├╴'verb'
#       │ │ ├─╮ 'class'
#       │ │ │ ├╴'weak'
#       │ │ │ ├╴'strong'
#       │ │ │ ╰╴'irregular'
#       │ │╶│╴ ╶╌╌╌╌╌╴
#       │ │ ╰─╮ 'transitivity'
#       │ │   ├╴'transitive'
#       │ │   ╰╴'intransitive'
#       │╶│╌╌╌╌╌╌╴
#       │ ├╴'noun'
#       │ │ ├─╮ 'gender'
#       │ │ │ ├╴'male'
#       │ │ │ ├╴'female'
#       │ │ │ ╰╴'neuter'
#       │ │╶│╴ ╶╌╌╌╌╌╴
#       │ │ ╰──╴'property': 'proper'
#       │╶│╌╌╌╌╌╌╴
#       │ ├╴'pronoun'
#       │ │ ├─╮ 'class'
#       │ │ │ ├╴'indefinite'
#       │ │ │ ╰╴'demonstrative'
#       │ │╶│╴ ╶╌╌╌╌╌╴
#       │ │ ├─╮ 'inflection'
#       │ │ │ ├╴'personal'
#       │ │ │ ├╴'posessive'
#       │ │ │ ╰╴'reflexive'
#       │ │╶│╴ ╶╌╌╌╌╌╴
#       │ │ ╰─╮ 'interrogation'
#       │ │   ├╴'interrogative'
#       │ │   ╰╴'relative'
#       │╶│╌╌╌╌╌╌╴
#       │ ├╴'adjective'
#       │ │ ╰─╮ 'class'
#       │ │   ├╴'gradable'
#       │ │   ╰╴'non-gradable'
#       │╶│╌╌╌╌╌╌╴
#       │ ├╴'adverb'
#       │ ├╴'preposition'
#       │╶│╌╌╌╌╌╌╴
#       │ ╰╴'conjunction'
#       │   ╰─╮ 'class'
#       │     ├╴'subordinate'
#       │     ╰╴'coordinate'
#      ╶│╴ ╶╌╌╌╌╌╴
#       ├──╴'numeric': 'numeral'
#       │   ╰─╮ 'class'
#       │     ├╴'cardinal'
#       │     ╰╴'ordinal'
#      ╶│╴ ╶╌╌╌╌╌╴
#       ├──╴'interjection': 'interjection'
#      ╶│╴ ╶╌╌╌╌╌╴
#       ╰─╮ 'affix'
#         ├╴'prefix'
#         ╰╴'suffix'
# {'parents': ['word'], 'label': 'class', '_children': ['indefinite', 'definite'], '_depth': 2}
# ╶╴'verb'
#   ├─╮ 'class'
#   │ ├╴'weak'
#   │ ├╴'strong'
#   │ ╰╴'irregular'
#  ╶│╴ ╶╌╌╌╌╌╴
#   ╰─╮ 'transitivity'
#     ├╴'transitive'
#     ╰╴'intransitive'

# %%
dump = json.dumps(lexeme_pos_tree.to_dict())
print(TemplateTree.from_dict(json.loads(dump), jpn_pos_restrictions_file))
# Out:
# ╶╴'expression'
#   ╰──╴'segment': 'word'
#       ├─╮ 'class'
#       │ ├╴'verb'
#       │ │ ╰─╮ 'class'
#       │ │   ├╴'quintigrade'
#       │ │   │ ├──╴'ending': 'ra column'
#       │ │   │ ╰──╴'inflection': '-aru special class'
#       │ │  ╶│╌╌╌╌╌╌╴
#       │ │   ╰╴'monograde'
#       │ │     ╰──╴'class': 'upper class'
#       │╶│╌╌╌╌╌╌╴
#       │ ╰╴'noun'
#      ╶│╴ ╶╌╌╌╌╌╴
#       ╰──╴'affix': 'prefix'

# %%
lexeme_pos_tree = TemplateTree.parse([], pos_dict)
print(lexeme_pos_tree)
# Out:
# ╶╴'expression'
